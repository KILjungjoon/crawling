# %%
import re
import requests
from bs4 import BeautifulSoup
from time import sleep
import os

# %%
# 2020 year chart(2020년 시대별 차트)
# https://www.melon.com/chart/age/list.htm?idx=1&chartType=YE&chartGenre=POP&chartDate=2020&moved=Y
headers = {
    'User-Agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
                       '(KHTML, like Gecko) Chrome/68.0.3440.75 Safari/537.36')
    }
 
age_url ="https://www.melon.com/chart/age/list.htm"
 
params = {
    'idx':'1',
    'chartType':'YE',     # Related to a 10-year search(10년 단위로 검색과 관련)
    'chartGenre':'KPOP',  # KPOP is domestic, POP is foreign(국내 차트는 KPOP, 해외 차트는 POP으로 지정)
    'chartDate':'2020',   # Select Year(연도 지정)
    'moved':'Y',
}
response = requests.get(age_url, params=params, headers = headers)
soup = BeautifulSoup(response.text, 'html.parser')
 
# Get the index value of each tag together with the enumerate(enumerate로 각 tag의 index값을 함께 가져온다) 
# 1 at the end of the line means that it starts from 1. If not, it starts from 0(라인 마지막의 1은 1부터 시작한다는 의미. 없으면 0부터 시작)
# There are many "a tags". Only get "a tag" containing the "playSong" is imported from the href element(a태그가 많다. 그 중에서 href요소 안에서 playSong문자를 포함하는 a태그만 가져온다)
for i, tag in enumerate(soup.select('a[href*=playSong]'),1):
    title = tag.text    
    js = tag['href']

    # Unlike the TOP100 crawling, the year chart has a single quotation('') of songId(시대별차트는 TOP100 크롤링과는 달리 songId부분이 ''홑따옴표로 되어있다)
    # Therefore, the regular expression needs to be modified(따라서 정규표현식을 아래처럼 수정)
    matched = re.search(r",'(\d+)'",js)
    # print(matched.group(1))  # print songId. for example, group(1) is 32313543, group(0)is ,'32313543'
    
    if matched:
        # output songId with group (1) at the end of url(url 마지막에 group(1)으로 songId 출력)
        song_Id = matched.group(1)
        song_url = 'https://www.melon.com/song/detail.htm?songId=' + song_Id
        print(i,title, song_url)
# Out:
# 1 아무노래  https://www.melon.com/song/detail.htm?songId=32313543
# 2 METEOR  https://www.melon.com/song/detail.htm?songId=32224272
# 3 아로하  https://www.melon.com/song/detail.htm?songId=32491274
# 4 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야  https://www.melon.com/song/detail.htm?songId=32003395
# 5 에잇(Prod.&Feat. SUGA of BTS)  https://www.melon.com/song/detail.htm?songId=32578498
# 6 Blueming  https://www.melon.com/song/detail.htm?songId=32183386
# 7 늦은 밤 너의 집 앞 골목길에서  https://www.melon.com/song/detail.htm?songId=32156286
# 8 시작  https://www.melon.com/song/detail.htm?songId=32345931
# 9 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)  https://www.melon.com/song/detail.htm?songId=31737197
# 10 Psycho  https://www.melon.com/song/detail.htm?songId=32273582
# 11 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지  https://www.melon.com/song/detail.htm?songId=32061975
# 12 Dynamite  https://www.melon.com/song/detail.htm?songId=32872978
# 13 마음을 드려요  https://www.melon.com/song/detail.htm?songId=32378104
# 14 처음처럼  https://www.melon.com/song/detail.htm?songId=32486613
# 15 How You Like That  https://www.melon.com/song/detail.htm?songId=32720013
# 16 살짝 설렜어 (Nonstop)  https://www.melon.com/song/detail.htm?songId=32559781
# 17 ON  https://www.melon.com/song/detail.htm?songId=32399830
# 18 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)  https://www.melon.com/song/detail.htm?songId=31853557
# 19 Downtown Baby  https://www.melon.com/song/detail.htm?songId=30773554
# 20 마리아 (Maria)  https://www.melon.com/song/detail.htm?songId=32725013
# 21 어떻게 지내 (Prod. By VAN.C)  https://www.melon.com/song/detail.htm?songId=32438894
# 22 모든 날, 모든 순간 (Every day, Every Moment)  https://www.melon.com/song/detail.htm?songId=30962526
# 23 다시 여기 바닷가  https://www.melon.com/song/detail.htm?songId=32790516
# 24 Dolphin  https://www.melon.com/song/detail.htm?songId=32559782
# 25 사랑하게 될 줄 알았어  https://www.melon.com/song/detail.htm?songId=32614125
# 26 안녕  https://www.melon.com/song/detail.htm?songId=31984204
# 27 그때 그 아인  https://www.melon.com/song/detail.htm?songId=32377231
# 28 취기를 빌려 (취향저격 그녀 X 산들)  https://www.melon.com/song/detail.htm?songId=32794652
# 29 Love poem  https://www.melon.com/song/detail.htm?songId=32143487
# 30 HIP  https://www.melon.com/song/detail.htm?songId=32175937
# 31 우리 왜 헤어져야 해  https://www.melon.com/song/detail.htm?songId=32187544
# 32 좋은 사람 있으면 소개시켜줘  https://www.melon.com/song/detail.htm?songId=32473998
# 33 너를 사랑하고 있어  https://www.melon.com/song/detail.htm?songId=32298623
# 34 봄날  https://www.melon.com/song/detail.htm?songId=30244931
# 35 Black Swan  https://www.melon.com/song/detail.htm?songId=32323969
# 36 Summer Hate (Feat. 비)  https://www.melon.com/song/detail.htm?songId=32734372
# 37 나비와 고양이 (feat.백현 (BAEKHYUN))  https://www.melon.com/song/detail.htm?songId=32583036
# 38 다시 난, 여기  https://www.melon.com/song/detail.htm?songId=32311870
# 39 눈누난나 (NUNU NANA)  https://www.melon.com/song/detail.htm?songId=32825454
# 40 돌덩이  https://www.melon.com/song/detail.htm?songId=32361098
# 41 오래된 노래  https://www.melon.com/song/detail.htm?songId=3894276
# 42 사랑이란 멜로는 없어  https://www.melon.com/song/detail.htm?songId=32034629
# 43 반만  https://www.melon.com/song/detail.htm?songId=32224409
# 44 시든 꽃에 물을 주듯  https://www.melon.com/song/detail.htm?songId=31703498
# 45 너를 만나  https://www.melon.com/song/detail.htm?songId=31388145
# 46 Square (2017)  https://www.melon.com/song/detail.htm?songId=32243273
# 47 FIESTA  https://www.melon.com/song/detail.htm?songId=32381408
# 48 덤더럼 (Dumhdurum)  https://www.melon.com/song/detail.htm?songId=32528369
# 49 아마두 (feat.우원재, 김효은, 넉살, Huckleberry P)  https://www.melon.com/song/detail.htm?songId=32228058
# 50 조금 취했어 (Prod. 2soo)  https://www.melon.com/song/detail.htm?songId=32059630
# 51 00:00 (Zero O’Clock)  https://www.melon.com/song/detail.htm?songId=32399832
# 52 When We Disco (Duet with 선미)  https://www.melon.com/song/detail.htm?songId=32853712
# 53 이제 나만 믿어요  https://www.melon.com/song/detail.htm?songId=32508053
# 54 보라빛 밤 (pporappippam)  https://www.melon.com/song/detail.htm?songId=32725022
# 55 WANNABE  https://www.melon.com/song/detail.htm?songId=32445339
# 56 홀로  https://www.melon.com/song/detail.htm?songId=32808616
# 57 화려하지 않은 고백  https://www.melon.com/song/detail.htm?songId=32508146
# 58 MORE & MORE  https://www.melon.com/song/detail.htm?songId=32636656
# 59 Lovesick Girls  https://www.melon.com/song/detail.htm?songId=32961718
# 60 Into the I-LAND  https://www.melon.com/song/detail.htm?songId=32698765
# 61 포장마차  https://www.melon.com/song/detail.htm?songId=31873020
# 62 친구  https://www.melon.com/song/detail.htm?songId=32399834
# 63 사랑은 지날수록 더욱 선명하게 남아  https://www.melon.com/song/detail.htm?songId=32651098
# 64 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)  https://www.melon.com/song/detail.htm?songId=32871975
# 65 빌었어  https://www.melon.com/song/detail.htm?songId=32224271
# 66 다시 만날까 봐  https://www.melon.com/song/detail.htm?songId=32021744
# 67 다시는 사랑하지 않고, 이별에 아파하기 싫어  https://www.melon.com/song/detail.htm?songId=32271720
# 68 사랑에 연습이 있었다면 (Prod. 2soo)  https://www.melon.com/song/detail.htm?songId=31324607
# 69 Filter  https://www.melon.com/song/detail.htm?songId=32399827
# 70 사랑이 식었다고 말해도 돼  https://www.melon.com/song/detail.htm?songId=31829536
# 71 DON'T TOUCH ME  https://www.melon.com/song/detail.htm?songId=32978341
# 72 나의 오랜 연인에게  https://www.melon.com/song/detail.htm?songId=32226962
# 73 마음이 말하는 행복 (Happiness) (Feat.이라온)  https://www.melon.com/song/detail.htm?songId=32282389
# 74 그 여름을 틀어줘  https://www.melon.com/song/detail.htm?songId=32814383
# 75 여름 안에서 by 싹쓰리 (Feat. 황광희)  https://www.melon.com/song/detail.htm?songId=32768945
# 76 주저하는 연인들을 위해  https://www.melon.com/song/detail.htm?songId=31666417
# 77 Moon  https://www.melon.com/song/detail.htm?songId=32399835
# 78 니 소식  https://www.melon.com/song/detail.htm?songId=31788850
# 79 그대 고운 내사랑  https://www.melon.com/song/detail.htm?songId=32521396
# 80 거짓말이라도 해서 널 보고싶어  https://www.melon.com/song/detail.htm?songId=32777869
# 81 힘든 건 사랑이 아니다  https://www.melon.com/song/detail.htm?songId=32998018
# 82 시차  https://www.melon.com/song/detail.htm?songId=32399828
# 83 있어줘요  https://www.melon.com/song/detail.htm?songId=32085144
# 84 기억해줘요 내 모든 날과 그때를  https://www.melon.com/song/detail.htm?songId=31967064
# 85 어느 60대 노부부이야기  https://www.melon.com/song/detail.htm?songId=32397381
# 86 헤어진 우리가 지켜야 할 것들  https://www.melon.com/song/detail.htm?songId=32224383
# 87 둘만의 세상으로 가  https://www.melon.com/song/detail.htm?songId=32364000
# 88 취했나봐  https://www.melon.com/song/detail.htm?songId=32616054
# 89 새 사랑  https://www.melon.com/song/detail.htm?songId=32091557
# 90 덤디덤디 (DUMDi DUMDi)  https://www.melon.com/song/detail.htm?songId=32833393
# 91 We are Bulletproof : the Eternal  https://www.melon.com/song/detail.htm?songId=32399837
# 92 BAND  https://www.melon.com/song/detail.htm?songId=31854689
# 93 깡 Official Remix  https://www.melon.com/song/detail.htm?songId=32646938
# 94 그대라는 시  https://www.melon.com/song/detail.htm?songId=31938460
# 95 Inner Child  https://www.melon.com/song/detail.htm?songId=32399833
# 96 사계 (Four Seasons)  https://www.melon.com/song/detail.htm?songId=31688205
# 97 찐이야  https://www.melon.com/song/detail.htm?songId=32457751
# 98 비  https://www.melon.com/song/detail.htm?songId=8235260
# 99 너에게 난, 나에게 넌  https://www.melon.com/song/detail.htm?songId=32631950
# 100 어떤 날엔  https://www.melon.com/song/detail.htm?songId=32323639
